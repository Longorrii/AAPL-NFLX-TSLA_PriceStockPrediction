# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
import tensorflow as tf

# %%
def split_data(df, choose):
  if choose == 1: # 7:2:1
    train_size = int(len(df) * 0.7)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 2: # 5:3:2
    train_size = int(len(df) * 0.5)
    test_size = int(len(df) * 0.3)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  elif choose == 3: # 6:2:2
    train_size = int(len(df) * 0.6)
    test_size = int(len(df) * 0.2)
    val_size = len(df) - train_size - test_size

    train_data = df[:train_size]
    test_data = df[train_size:train_size + test_size]
    val_data = df[train_size + test_size:]

  print("Train: ", train_size)
  print("Test: ", test_size)
  print("Val: ", val_size)

  return train_data, test_data, val_data

# %%
# load the dataset
df = pd.read_csv('/content/drive/MyDrive/IS403.N22/Project/dataset/TSLA_Stock.csv',usecols=['Date', 'Price'], parse_dates=['Date'], index_col='Date')
df.head()
# Out:
#             Price
# Date
# 2017-12-01  20.44
# 2017-12-04  20.35
# 2017-12-05  20.25
# 2017-12-06  20.88
# 2017-12-07  20.75

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df.values)

train_data, test_data, val_data = split_data(scaled_data, 1)
# Out:
# Train:  974
# Test:  278
# Val:  140

# %%
# define the number of time steps and features
n_steps = 10
n_features = 1

# Tạo hàm input sequences
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i + n_steps])
        y.append(data[i + n_steps])
    return np.array(X), np.array(y)

# Tạo input sequences cho training, validation, và testing
X_train, y_train = create_sequences(train_data, n_steps)
X_val, y_val = create_sequences(val_data, n_steps)
X_test, y_test = create_sequences(test_data, n_steps)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
X_val = X_val.reshape(X_val.shape[0],X_val.shape[1] , 1)

# %%
model = Sequential()
model.add(tf.keras.layers.LSTM(50,return_sequences=True, input_shape=(n_steps, n_features)))
model.add(tf.keras.layers.LSTM(50))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 10, 50)            10400
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 30,651
# Trainable params: 30,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')#, metrics=[MeanAbsolutePercentageError()])
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 31/31 [==============================] - 5s 41ms/step - loss: 0.0175 - val_loss: 0.0057
# Epoch 2/100
# 31/31 [==============================] - 0s 15ms/step - loss: 7.5060e-04 - val_loss: 0.0039
# Epoch 3/100
# 31/31 [==============================] - 0s 15ms/step - loss: 5.0150e-04 - val_loss: 0.0039
# Epoch 4/100
# 31/31 [==============================] - 0s 15ms/step - loss: 4.8649e-04 - val_loss: 0.0039
# Epoch 5/100
# 31/31 [==============================] - 0s 15ms/step - loss: 4.5844e-04 - val_loss: 0.0037
# Epoch 6/100
# 31/31 [==============================] - 1s 20ms/step - loss: 4.4775e-04 - val_loss: 0.0038
# Epoch 7/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.4841e-04 - val_loss: 0.0036
# Epoch 8/100
# 31/31 [==============================] - 1s 25ms/step - loss: 4.4493e-04 - val_loss: 0.0034
# Epoch 9/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.4632e-04 - val_loss: 0.0034
# Epoch 10/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.2665e-04 - val_loss: 0.0037
# Epoch 11/100
# 31/31 [==============================] - 1s 23ms/step - loss: 4.1395e-04 - val_loss: 0.0042
# Epoch 12/100
# 31/31 [==============================] - 1s 24ms/step - loss: 4.4426e-04 - val_loss: 0.0033
# Epoch 13/100
# 31/31 [==============================] - 0s 15ms/step - loss: 4.0328e-04 - val_loss: 0.0042
# Epoch 14/100
# 31/31 [==============================] - 0s 16ms/step - loss: 3.9757e-04 - val_loss: 0.0031
# Epoch 15/100
# 31/31 [==============================] - 0s 16ms/step - loss: 4.0749e-04 - val_loss: 0.0042
# Epoch 16/100
# 31/31 [==============================] - 0s 15ms/step - loss: 4.5015e-04 - val_loss: 0.0033
# Epoch 17/100
# 31/31 [==============================] - 0s 15ms/step - loss: 3.8208e-04 - val_loss: 0.0030
# Epoch 18/100
# 31/31 [==============================] - 0s 16ms/step - loss: 3.8644e-04 - val_loss: 0.0029
# Epoch 19/100
# 31/31 [==============================] - 1s 16ms/step - loss: 4.3392e-04 - val_loss: 0.0034
# Epoch 20/100
# 31/31 [==============================] - 0s 16ms/step - loss: 3.5928e-04 - val_loss: 0.0029
# Epoch 21/100
# 31/31 [==============================] - 1s 18ms/step - loss: 3.4411e-04 - val_loss: 0.0039
# Epoch 22/100
# 31/31 [==============================] - 1s 21ms/step - loss: 4.6922e-04 - val_loss: 0.0040
# Epoch 23/100
# 31/31 [==============================] - 1s 27ms/step - loss: 3.9516e-04 - val_loss: 0.0032
# Epoch 24/100
# 31/31 [==============================] - 1s 27ms/step - loss: 3.3699e-04 - val_loss: 0.0030
# Epoch 25/100
# 31/31 [==============================] - 0s 15ms/step - loss: 3.2891e-04 - val_loss: 0.0028
# Epoch 26/100
# 31/31 [==============================] - 0s 15ms/step - loss: 3.3197e-04 - val_loss: 0.0035
# Epoch 27/100
# 31/31 [==============================] - 0s 16ms/step - loss: 3.4666e-04 - val_loss: 0.0026
# Epoch 28/100
# 31/31 [==============================] - 0s 16ms/step - loss: 3.2392e-04 - val_loss: 0.0024
# Epoch 29/100
# 31/31 [==============================] - 0s 15ms/step - loss: 4.1650e-04 - val_loss: 0.0031
# Epoch 30/100
# 31/31 [==============================] - 0s 15ms/step - loss: 3.5020e-04 - val_loss: 0.0023
# Epoch 31/100
# 31/31 [==============================] - 1s 22ms/step - loss: 3.0339e-04 - val_loss: 0.0022
# Epoch 32/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.8920e-04 - val_loss: 0.0020
# Epoch 33/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.8751e-04 - val_loss: 0.0020
# Epoch 34/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.6353e-04 - val_loss: 0.0029
# Epoch 35/100
# 31/31 [==============================] - 1s 24ms/step - loss: 3.1751e-04 - val_loss: 0.0022
# Epoch 36/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.9799e-04 - val_loss: 0.0025
# Epoch 37/100
# 31/31 [==============================] - 1s 21ms/step - loss: 2.6923e-04 - val_loss: 0.0026
# Epoch 38/100
# 31/31 [==============================] - 0s 16ms/step - loss: 2.8465e-04 - val_loss: 0.0034
# Epoch 39/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.6847e-04 - val_loss: 0.0018
# Epoch 40/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.8751e-04 - val_loss: 0.0020
# Epoch 41/100
# 31/31 [==============================] - 0s 16ms/step - loss: 2.6399e-04 - val_loss: 0.0025
# Epoch 42/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.3880e-04 - val_loss: 0.0017
# Epoch 43/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.6388e-04 - val_loss: 0.0018
# Epoch 44/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.8885e-04 - val_loss: 0.0019
# Epoch 45/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.5005e-04 - val_loss: 0.0016
# Epoch 46/100
# 31/31 [==============================] - 0s 16ms/step - loss: 2.4984e-04 - val_loss: 0.0019
# Epoch 47/100
# 31/31 [==============================] - 0s 16ms/step - loss: 2.4509e-04 - val_loss: 0.0028
# Epoch 48/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.6449e-04 - val_loss: 0.0016
# Epoch 49/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.3198e-04 - val_loss: 0.0016
# Epoch 50/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.4584e-04 - val_loss: 0.0016
# Epoch 51/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2137e-04 - val_loss: 0.0019
# Epoch 52/100
# 31/31 [==============================] - 0s 16ms/step - loss: 2.2824e-04 - val_loss: 0.0016
# Epoch 53/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2748e-04 - val_loss: 0.0028
# Epoch 54/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.5303e-04 - val_loss: 0.0018
# Epoch 55/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2937e-04 - val_loss: 0.0015
# Epoch 56/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.4239e-04 - val_loss: 0.0014
# Epoch 57/100
# 31/31 [==============================] - 0s 14ms/step - loss: 2.1537e-04 - val_loss: 0.0021
# Epoch 58/100
# 31/31 [==============================] - 1s 20ms/step - loss: 2.4467e-04 - val_loss: 0.0022
# Epoch 59/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.3298e-04 - val_loss: 0.0014
# Epoch 60/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.0549e-04 - val_loss: 0.0015
# Epoch 61/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.9652e-04 - val_loss: 0.0014
# Epoch 62/100
# 31/31 [==============================] - 1s 24ms/step - loss: 2.0685e-04 - val_loss: 0.0017
# Epoch 63/100
# 31/31 [==============================] - 1s 26ms/step - loss: 2.3829e-04 - val_loss: 0.0015
# Epoch 64/100
# 31/31 [==============================] - 1s 21ms/step - loss: 2.1924e-04 - val_loss: 0.0017
# Epoch 65/100
# 31/31 [==============================] - 1s 16ms/step - loss: 1.9553e-04 - val_loss: 0.0021
# Epoch 66/100
# 31/31 [==============================] - 0s 14ms/step - loss: 2.1975e-04 - val_loss: 0.0015
# Epoch 67/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.1633e-04 - val_loss: 0.0027
# Epoch 68/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.4116e-04 - val_loss: 0.0013
# Epoch 69/100
# 31/31 [==============================] - 1s 17ms/step - loss: 1.9593e-04 - val_loss: 0.0013
# Epoch 70/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.8110e-04 - val_loss: 0.0013
# Epoch 71/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.0040e-04 - val_loss: 0.0015
# Epoch 72/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.9726e-04 - val_loss: 0.0017
# Epoch 73/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.0187e-04 - val_loss: 0.0015
# Epoch 74/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.9922e-04 - val_loss: 0.0015
# Epoch 75/100
# 31/31 [==============================] - 0s 16ms/step - loss: 1.9210e-04 - val_loss: 0.0012
# Epoch 76/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.9812e-04 - val_loss: 0.0016
# Epoch 77/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2879e-04 - val_loss: 0.0013
# Epoch 78/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.9973e-04 - val_loss: 0.0012
# Epoch 79/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.8315e-04 - val_loss: 0.0018
# Epoch 80/100
# 31/31 [==============================] - 0s 16ms/step - loss: 1.7505e-04 - val_loss: 0.0011
# Epoch 81/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.1158e-04 - val_loss: 0.0011
# Epoch 82/100
# 31/31 [==============================] - 1s 17ms/step - loss: 1.7478e-04 - val_loss: 0.0013
# Epoch 83/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2942e-04 - val_loss: 0.0011
# Epoch 84/100
# 31/31 [==============================] - 0s 16ms/step - loss: 1.7311e-04 - val_loss: 0.0011
# Epoch 85/100
# 31/31 [==============================] - 1s 19ms/step - loss: 1.7062e-04 - val_loss: 0.0011
# Epoch 86/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.7329e-04 - val_loss: 0.0014
# Epoch 87/100
# 31/31 [==============================] - 1s 23ms/step - loss: 2.5706e-04 - val_loss: 0.0011
# Epoch 88/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.6401e-04 - val_loss: 0.0015
# Epoch 89/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.6662e-04 - val_loss: 0.0012
# Epoch 90/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.7074e-04 - val_loss: 0.0012
# Epoch 91/100
# 31/31 [==============================] - 1s 24ms/step - loss: 1.9629e-04 - val_loss: 0.0013
# Epoch 92/100
# 31/31 [==============================] - 0s 16ms/step - loss: 1.9231e-04 - val_loss: 0.0010
# Epoch 93/100
# 31/31 [==============================] - 1s 16ms/step - loss: 1.5639e-04 - val_loss: 0.0012
# Epoch 94/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.6742e-04 - val_loss: 0.0010
# Epoch 95/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.7312e-04 - val_loss: 0.0011
# Epoch 96/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.6550e-04 - val_loss: 0.0010
# Epoch 97/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.7223e-04 - val_loss: 0.0015
# Epoch 98/100
# 31/31 [==============================] - 0s 15ms/step - loss: 2.2109e-04 - val_loss: 0.0011
# Epoch 99/100
# 31/31 [==============================] - 0s 16ms/step - loss: 1.5333e-04 - val_loss: 0.0011
# Epoch 100/100
# 31/31 [==============================] - 0s 15ms/step - loss: 1.5857e-04 - val_loss: 9.9837e-04

# %%
# evaluate trên tập test
loss_test = model.evaluate(X_test, y_test, verbose=0)
print("loss_test: ", loss_test)

# evaluate trên tập val
loss_val = model.evaluate(X_val, y_val, verbose=0)
print("loss_val: ", loss_val)
# Out:
# loss_test:  0.000998365692794323
# loss_val:  0.0004149817686993629

# %%
def mae_rmse_mape(true, predict):
  mae = mean_absolute_error(true, predict)
  rmse = np.sqrt(mean_squared_error(true, predict))
  mape = mean_absolute_percentage_error(true, predict)

  return mae, rmse, mape

# %%
y_pred_test = model.predict(X_test)
y_pred_val = model.predict(X_val)

# y_pred_test = y_pred_test.reshape(-1,1)
# y_pred_val = y_pred_val.reshape(-1,1)

# y_pred_test = scaler.inverse_transform(y_pred_test)
# y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 9/9 [==============================] - 1s 6ms/step
# 5/5 [==============================] - 0s 5ms/step

# %%
y_pred_test = scaler.inverse_transform(y_pred_test)
y_pred_val = scaler.inverse_transform(y_pred_val)

y_test = scaler.inverse_transform(y_test)
y_val = scaler.inverse_transform(y_val)
y_train = scaler.inverse_transform(y_train)

# %%
# y_pred_test = y_pred_test.reshape(y_test.shape[0], 1)
# y_pred_val = y_pred_val.reshape(y_val.shape[0], 1)

# %%
mae_test, rmse_test, mape_test = mae_rmse_mape(y_test, y_pred_test)
mae_val, rmse_val, mape_val = mae_rmse_mape(y_val, y_pred_val)

print('MAE of Test: ', mae_test)
print('RMSE of Test: ', rmse_test)
print('MAPE of Test: ', mape_test)
print('------------------------')
print('MAE of Validation: ', mae_val)
print('RMSE of Validation: ', rmse_val)
print('MAPE of Validation: ', mape_val)
# Out:
# MAE of Test:  9.688024205449802
# RMSE of Test:  12.576837454505663
# MAPE of Test:  0.034340981671400955
# ------------------------
# MAE of Validation:  6.461036508413462
# RMSE of Validation:  8.10851525865539
# MAPE of Validation:  0.03903069478343807

# %%
number_days = 30

last_sequence = X_val[-1:]

predicted_values = []

for _ in range(number_days):
    next_value = model.predict(last_sequence)
    predicted_values.append(next_value[0, 0])
    last_sequence = np.append(last_sequence[:, 1:, :], [next_value], axis=1)

# %%
predicted_values = scaler.inverse_transform(np.array(predicted_values).reshape(-1, 1))
#predicted_values = np.array(predicted_values).reshape(-1, 1)

# %%
plt.figure(figsize=(12,6))

plt.plot(range(len(y_train)), y_train, label='Train')

plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label='Test')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_pred_test, label='Test Prediction')

plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_val, label='Validation')
plt.plot(range(len(y_train) + len(y_test), len(y_train) + len(y_test) + len(y_val)), y_pred_val, label='Validation Prediction')

plt.plot(range(len(y_train) + len(y_test) + len(y_val), len(y_train) + len(y_test) + len(y_val) + number_days), predicted_values, label='30days_Next')

plt.legend()
plt.show()

# %%
# dates = df.index

# # Plot the training data
# plt.figure(figsize=(12, 6))
# plt.plot(dates[:len(y_train)], y_train, label='Train')

# # Plot the validation data
# test_offset = len(y_train)
# plt.plot(dates[test_offset:test_offset + len(y_test)], y_test, label='Test')
# plt.plot(dates[test_offset:test_offset + len(y_pred_test)], y_pred_test, label='Test Predictions')

# # Plot the testing data
# val_offset = test_offset + len(y_test)
# plt.plot(dates[val_offset:val_offset + len(y_val)], y_val, label='Validation')
# plt.plot(dates[val_offset:val_offset + len(y_pred_val)], y_pred_val, label='Validation Predictions')

# next30days_offset = pd.date_range(start=dates[-1], periods=31, closed='right')
# plt.plot(next30days_offset, predicted_values, label='30 next days')

# plt.xticks(rotation=45)

# plt.legend()
# plt.show()
